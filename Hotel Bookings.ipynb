# %% [markdown]
# # EDA on Hotel Booking
# ## By Rahul Inchal

# %% [markdown]
# ## Project Summary
# This project is related to Hotel Booking having two hotel description i.e City Hotel and Resort Hotel. In this dataset contains total rows  119390 and 32 columns.In this we divide data manipulation workflow in three category Data Collection ,Data cleaning and manipulation and EDA(Exploratory Data Analysis).As Further moved i.e Data collections first step to find different columns which is done by coding Head(), tail(), info(), describe(), columns() and some others method used for data collections, some of the columns name is updated here i.e hotel,is_canceled,lead_time,arrival_date_year,arrival_date_month,arrival_date_week_number,arrival_date_day_of_month,stays_in_weekend_nights.As we further moved we find unique value of each columns and generate a list in tabular form and also check the dataset type of each columns’ find some columns not in accurate data types which correct it later done  in Data cleaning part and as well as duplicates data items must be removed as we find duplicates items equal  to 87396 which is dropped from dataset later.
#
# Before visualize any data from the data set we have to do data wrangling.
# For that, we are checked the null value of all the columns. After checking, when we are getting a column which has more number of null values, dropped that column by using the 'drop' method. In this way, we are dropped the 'company' column. When we are find minimal number of null values, filling thse null values with necesary values as per requirement by using .fillna()
#
#
#
# Different charts are used for data visualization so that better insights and Business objective is attained.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ## GitHub link
# https://github.com/rahulinchal/EDA-on-Hotel-Bookings-

# %% [markdown]
# ## General Guideline
#
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ### Chart visualization code
#
#
# * Why did you pick the specific chart?
# * What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# * Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
#         [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis

# %% [markdown]
# ![Top-Luxury-Hotels-in-Mumbai.jpg](attachment:Top-Luxury-Hotels-in-Mumbai.jpg)

# %% [markdown]
# ## Importing Important Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
# reading the csv file
data = pd.read_csv('C:/Users\Rahul\Desktop\Resume/Hotel Bookings.csv')

# getting all the data column
pd.set_option('display.max_columns', None)

# extracting the top 5 rows
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ## Data Description

# %% [markdown]
# ## ![Screenshot%20%282709%29.png](attachment:Screenshot%20%282709%29.png)

# %% [markdown]
# 1. **hotel** : *Hotel(Resort Hotel or City Hotel)*
#
# 2. **is_canceled** : *Value indicating if the booking was canceled (1) or not (0)*
#
# 3. **lead_time** :* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# 4. **arrival_date_year** : *Year of arrival date*
#
# 5. **arrival_date_month** : *Month of arrival date*
#
# 6. **arrival_date_week_number** : *Week number of year for arrival date*
#
# 7. **arrival_date_day_of_month** : *Day of arrival date*
#
# 8. **stays_in_weekend_nights** : *Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel*
#
# 9. **stays_in_week_nights** : *Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel*
#
# 10. **adults** : *Number of adults*
#
# 11. **children** : *Number of children*
#
# 12. **babies** : *Number of babies*
#
# 13. **meal** : *Type of meal booked. Categories are presented in standard hospitality meal packages:*
#
# 14. **country** : *Country of origin.`*
#
# 15. **market_segment** : *Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 16. **distribution_channel** : *Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 17. **is_repeated_guest** : *Value indicating if the booking name was from a repeated guest (1) or not (0)*
#
# 18. **previous_cancellations** : *Number of previous bookings that were cancelled by the customer prior to the current booking*
#
# 19. **previous_bookings_not_canceled** : *Number of previous bookings not cancelled by the customer prior to the current booking*
#
# 20. **reserved_room_type** : *Code of room type reserved. Code is presented instead of designation for anonymity reasons.*
#
# 21. **assigned_room_type** : *Code for the type of room assigned to the booking.*
#
# 22. **booking_changes** : *Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation*
#
# 23. **deposit_type** : *Indication on if the customer made a deposit to guarantee the booking.*
#
# 24. **agent** : *ID of the travel agency that made the booking*
#
# 25. **company** : *ID of the company/entity that made the booking or responsible for paying the booking.*
#
# 26. **days_in_waiting_list** : *Number of days the booking was in the waiting list before it was confirmed to the customer*
#
# 27. **customer_type** : *Type of booking, assuming one of four categories*
#
#
# 28. **adr** : *Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights*
#
# 29. **required_car_parking_spaces** : *Number of car parking spaces required by the customer*
#
# 30. **total_of_special_requests** :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# 31. **reservation_status** : *Reservation last status, assuming one of three categories*
# * Canceled – booking was canceled by the customer
# * Check-Out – customer has checked in but already departed
# * No-Show – customer did not check-in and did inform the hotel of the reason why
#
#
#
#
#
# 32. **reservation_status_date** : *Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel*

# %% [markdown]
# ## Data Exploration

# %%
# Creating the copy of the data as df
df = data.copy()

# %%
# Checking the shape
df.shape
# Out:
# (119390, 32)

# %%
#Getitng the information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Shape before dropping all the duplicated columns
df.shape
# Out:
# (119390, 32)

# %%
# Finding the Duplicate Values
duplicates = df.duplicated().value_counts()
duplicates
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = df.duplicated())
plt.title("Count of Duplicated values")
plt.grid()

# %%
# Dropping all the duplicated columns
df = df.drop_duplicates()

# %%
# Shape after dropping all the duplicated columns
df.shape
# Out:
# (87396, 32)

# %%
#checking for null values
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visulaizing null values through heatmap.
plt.figure(figsize=(25, 10))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False,cmap='viridis')
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# ## Checking for outliers

# %%
plt.figure(figsize = (10,5))
sns.boxplot(df['agent'], color = 'orange')
# Out:
# <AxesSubplot:xlabel='agent'>

# %%
plt.figure(figsize = (10,5))
sns.boxplot(df['company'], color = 'orange')
# Out:
# <AxesSubplot:xlabel='company'>

# %%
plt.figure(figsize = (10,5))
sns.boxplot(df['children'], color = 'orange')
# Out:
# <AxesSubplot:xlabel='children'>

# %%
df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# ### After dropoing all the duplicated values, there are not much of outliers present in the data except for children. Not dropping the extreme values as it is not extreme.

# %%
#filling 'others' in place of null values in country
df['country'].fillna('others', inplace = True)

# Replacing null values with 0 of agent column
df['agent'].replace(np.nan, 0, inplace = True)

# Replacing null values with 0 of company column
df['company'].replace(np.nan, 0, inplace = True)

# Replacing nan values with mean in children column
mean1 = df['children'].mean
df['children'].replace(np.nan, mean1, inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# Creating a column which contain total people including adult babies and children
df_people = ['adults','babies', 'children']
df['total_people'] = df[df_people].sum(axis = 1)

# finding the unique values of total people
df['total_people'].unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10, 12],
#       dtype=int64)

# %% [markdown]
# ### Dropping all the rows with 0 people in total people because 0 indicates no booking were made or no one checked into the hotel

# %%
df.drop(df[df['total_people'] == 0].index, inplace = True)
df['total_people'].unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55, 20,  6,  5, 10, 12],
#       dtype=int64)

# %%
# Creating a column which contain total people who stayed in the hotel
df_stayed = ['stays_in_weekend_nights', 'stays_in_week_nights']
df['total_stayed'] = df[df_stayed].sum(axis = 1)

# %%
df.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# ...

# %%
df.shape
# Out:
# (87014, 34)

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %% [markdown]
# # Exploratory Data Analysis
# ## Univariate Analysis

# %% [markdown]
# ### 1. Which Hotel is preffered by people

# %%
hotel_type = df['hotel'].value_counts()
hotel_type
# Out:
# City Hotel      53058
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
textprops = {"fontsize":15} # Font size of text in pie chart
plt.figure(figsize = (7,7)) # fixing pie chart size
plt.pie(hotel_type, labels = hotel_type.keys(), colors =('y','r'), shadow = True, autopct='%1.1f%%', textprops =textprops)
plt.legend()
plt.title("Type of Hotel preffered by People")
# Out:
# Text(0.5, 1.0, 'Type of Hotel preffered by People')

# %% [markdown]
# ## Observations
# * People prefer City hotel than Resort Hotel.

# %% [markdown]
# ### 2. What is the percentage of people cancelling the hotel

# %%
cancelled_or_not = df['is_canceled'].value_counts()
cancelled_or_not
# Out:
# 0    63085
# 1    23929
# Name: is_canceled, dtype: int64

# %%
textprops = {"fontsize":15} # Font size of text in pie chart
plt.figure(figsize = (7,7)) # fixing pie chart size
plt.pie(cancelled_or_not, labels = cancelled_or_not.keys(), colors =('g','b'), 
        shadow = True, autopct='%1.1f%%', textprops =textprops)
labels = ('0 = Booked', '1 = Cancelled')
plt.legend(labels)
plt.title("Percentage of people cancelling the hotel")
# Out:
# Text(0.5, 1.0, 'Percentage of people cancelling the hotel')

# %% [markdown]
# ## Observations
# * 0 means Booked
# * 1 means Cancelled
# * 27.5% of the bookings were cancelled

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %% [markdown]
# ## 3. Which agent made the most number of booking

# %%
df['agent'].unique()
# Out:
# array([  0., 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
# Checking if there are outliers

plt.figure(figsize = (10,5))
sns.boxplot(df['agent'])
# Out:
# <AxesSubplot:xlabel='agent'>

# %%
# Getting the top 10 agents

top_10_agents = df['agent'].value_counts().iloc[:10]
top_10_agents
# Out:
# 9.0      28548
# 240.0    13028
# 0.0      12124
# 14.0      3327
# 7.0       3290
# 250.0     2779
# 241.0     1644
# 28.0      1493
# 8.0       1380
# 1.0       1228
# Name: agent, dtype: int64

# %%
# Visualizing the top 10 agents who made bookings

plt.figure(figsize = (15,6))
df['agent'].value_counts().iloc[:10].plot(kind = 'bar', color = 'r')
plt.title("Top 10 Agents who made bookings")
plt.xlabel("Agents")
plt.ylabel("Number of bookings")
plt.xticks(rotation = 360)
plt.show()

# %% [markdown]
# ## Observations
# * Agent 9.0 made the most of the bookings

# %% [markdown]
# ## 4. What is the Percentage of repeated guests?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Finding Unique Values of Is_repeated_guests

df['is_repeated_guest'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Extracting how many repeated and new guest are there

df['is_repeated_guest'].value_counts()
# Out:
# 0    83651
# 1     3363
# Name: is_repeated_guest, dtype: int64

# %%
# Visualizing using Pie chart

textprops = {"fontsize":15} # Font size of text in pie chart
plt.figure(figsize = (7,7)) # fixing pie chart size
df['is_repeated_guest'].value_counts().plot(kind = 'pie', shadow = True, autopct='%1.1f%%', textprops =textprops)
labels = ['0 = New Guest', '1 = Repeated Guest']
plt.legend(labels)
plt.title('Percentage of repeated guests')
plt.show()

# %% [markdown]
# ## Observation
# * 1 = repeated guest
# * 0 = New Guests
# * There are very few repeated guest. hotel needs to work on the feedbacks which is give in order for the guests to return

# %% [markdown]
# ## 5. what is the percentage distribution of Customer Type

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Finding unique values

df['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
# Extracting the value counts

df['customer_type'].value_counts()
# Out:
# Transient          71728
# Transient-Party    11612
# Contract            3134
# Group                540
# Name: customer_type, dtype: int64

# %%
# Extracting the keys

df['customer_type'].value_counts().keys()
# Out:
# Index(['Transient', 'Transient-Party', 'Contract', 'Group'], dtype='object')

# %%
# Visualizing using Pie chart

textprops = {"fontsize":15} # Font size of text in pie chart
plt.figure(figsize = (7,7)) # fixing pie chart size
df['customer_type'].value_counts().plot(kind = 'pie', shadow = True, autopct='%1.1f%%', textprops =textprops)
plt.legend(df['customer_type'].value_counts().keys())                                       
plt.title('Distribution of Customer Type')
plt.show()

# %% [markdown]
# **1. Contract**
# -when the booking has an allotment or other type of contract associated to it
#
# **2. Group**
# -when the booking is associated to a group
#
# **3. Transient**
# -when the booking is not part of a group or contract, and is not associated to other transient booking
#
# **4. Transient-party**
# -when the booking is transient, but is associated to at least other transient booking
#
# ### **Observation:**
# * Transient customer type is more which is 82.4 %.
# * percentage of  Booking associated by the Group is vey low.

# %% [markdown]
# ### 6. What is the percentage distribution of required_car_parking_spaces?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting the unique values

df['required_car_parking_spaces'].unique()
# Out:
# array([0, 1, 2, 8, 3], dtype=int64)

# %%
# Finding the Value Counts

df['required_car_parking_spaces'].value_counts()
# Out:
# 0    79710
# 1     7271
# 2       28
# 3        3
# 8        2
# Name: required_car_parking_spaces, dtype: int64

# %%
# Visualizing Through Bar Graph

plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
df['required_car_parking_spaces'].value_counts().plot(kind = 'bar', color = 'g')
plt.title("Required Car Parking Space")
plt.xlabel("Number of Car spaces required")
plt.ylabel("Number of People")

# Visualizing Through Pie Graph

plt.subplot(1,2,2)
df['required_car_parking_spaces'].value_counts().plot(kind = 'pie',  
                                                      shadow = True, autopct='%1.2f%%', textprops =textprops)
plt.title('Percentage of Required car Parking Space')
plt.show()

# %% [markdown]
# ### **Observation**
# * 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# ## 7. What is the percentage of booking changes made by the customer?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting the unique values

df['booking_changes'].unique()
# Out:
# array([ 3,  4,  0,  1,  2,  5, 17,  6,  8,  7, 10, 16,  9, 13, 12, 14, 15,
#        18, 11], dtype=int64)

# %%
# Finding the Value Counts

df['booking_changes'].value_counts()
# Out:
# 0     71263
# 1     10825
# 2      3478
# 3       858
# 4       347
# 5       112
# 6        57
# 7        28
# 8        14
# 9         8
# 10        6
# 13        5
# 14        3
# 15        3
# 17        2
# 16        2
# 12        1
# 18        1
# 11        1
# Name: booking_changes, dtype: int64

# %%
# Visualizing using bar chart

plt.figure(figsize = (15,6))
df['booking_changes'].value_counts().plot(kind = 'bar', color = 'r')
plt.title("Number of booking changes made by guests")
plt.xlabel("Number of booking changes")
plt.ylabel("Number of Guests")
plt.xticks(rotation = 360)
plt.show()

# %% [markdown]
# ## Observations
# * 0 means no changes were made, 1 means only 1 changes made and so on.
# * Looks like most of the people prefer to make no changes.

# %% [markdown]
# ## 8. What is Percentage distribution of Deposite type ?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting the unique values

df['deposit_type'].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
# Finding the Value Counts

df['deposit_type'].value_counts()
# Out:
# No Deposit    85869
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %%
# Visualizing Through Bar Graph

plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
df['deposit_type'].value_counts().plot(kind = 'bar', color = 'g')
plt.title("Number of guests according to distribution Type")
plt.xlabel("Distribution Type")
plt.ylabel("Number of Guests")
plt.xticks(rotation = 360)

# Visualizing Through Pie Graph

plt.subplot(1,2,2)
df['deposit_type'].value_counts().plot(kind = 'pie',  
                                                shadow = True, autopct='%1.2f%%', textprops =textprops)
plt.title('Percentage of distribution Type')
plt.show()

# %% [markdown]
# ## Observation
# * 98.68% of people prefer no deposit Type

# %% [markdown]
# ## 9. Which type of food is mostly preferred by the guests?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting the unique values

df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
# Getting the value counts

df['meal'].value_counts()
# Out:
# BB           67697
# SC            9389
# HB            9076
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
# Visualizing using Pie chart

textprops = {"fontsize":15} # Font size of text in pie chart
plt.figure(figsize = (7,7)) # fixing pie chart size
df['meal'].value_counts().plot(kind = 'pie', shadow = True, autopct='%1.1f%%', textprops =textprops)
plt.legend(df['customer_type'].value_counts().keys())                                       
plt.title('Distribution of Customer Type')
plt.show()

# %%
# Visualizing Through Bar Graph

plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
df['meal'].value_counts().plot(kind = 'bar', color = 'y')
plt.title("Preffered meal")
plt.xlabel("Type of meal")
plt.ylabel("Number of Guests")
plt.xticks(rotation = 360)

# Visualizing Through Pie Graph

plt.subplot(1,2,2)
df['meal'].value_counts().plot(kind = 'pie',  
                                            shadow = True, autopct='%1.2f%%', textprops =textprops)
plt.legend(df['meal'].value_counts().keys())
plt.title('Percentage of Preffered meal')
plt.show()

# %% [markdown]
# * BB means bed and breakfast.
# * HB means half board, in which breakfast and dinner are included.
# * FB means full board, in which breakfast, lunch and dinner are included.
# * SC means Self-catering. The meals aren't included in the price, but the guests have access to the kitchen or kitchenette, where they can prepare the meals on their own.
# ## Observation
#
#
# * More than 77% of people prefer BB.
# * Self-Catering and Half Board is almost the same preffered.

# %% [markdown]
# ## 10. From which country the most guests are coming?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# finding the unique values

df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', 'others', 'ROU', 'NOR',
#        'OMN', 'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA',
#        'NLD', 'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN',
#        'MOZ', 'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR',
#        'UKR', 'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU',
#        'TUR', 'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA',
#        'KOR', 'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN',
#        'GEO', 'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY',
#        'KWT', 'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN',
#        'LBN', 'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM',
#        'MKD', 'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS',
#        'COM', 'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI',
#        'SAU', 'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU',
# ...

# %%
# Getting the value counts of top 10 countries

df['country'].value_counts().iloc[:10]
# Out:
# PRT    27314
# GBR    10409
# FRA     8798
# ESP     7230
# DEU     5372
# ITA     3053
# IRL     3011
# BEL     2065
# BRA     1983
# NLD     1901
# Name: country, dtype: int64

# %%
# Visualizing using bar chart

plt.figure(figsize = (20,8))
df['country'].value_counts().iloc[:10].plot(kind = 'bar', color = 'g')
plt.title("Countries from which most number of guests coming from ")
plt.xlabel("Countries")
plt.ylabel("Number of Guests")
plt.xticks(rotation = 360)
plt.show()

# %%
# Visualizing using Pie chart

textprops = {"fontsize":15} # Font size of text in pie chart
plt.figure(figsize = (7,7)) # fixing pie chart size
df['country'].value_counts().iloc[:10].plot(kind = 'pie', shadow = True, autopct='%1.1f%%', textprops =textprops)
plt.legend(df['country'].value_counts().keys())                                       
plt.title('Countries from which most number of guests coming from ')
plt.show()

# %% [markdown]
# * PRT - Portugal
# * GBR - United Kingdom • UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND.
# * FRA - France
# * ESP - E-S-P is short for Espahnia, which is the Spanish name for Spain.
# * DEU - Germany
# * ITA - Italy
# * IRL - Ireland
# * BEL - Belgium
# * BRA - Brazil
# * NLD - Netherlands
# ## Observations
# * Most of the Guests are coming from Portugal followed by United Kingdom

# %% [markdown]
# ## 11. Which is the most preferred room type by the customers?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# getting the unique values

df['assigned_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'I', 'B', 'H', 'L', 'K'],
#       dtype=object)

# %%
# Getting the value counts

df['assigned_room_type'].value_counts()
# Out:
# A    46247
# D    22416
# E     7190
# F     3627
# G     2494
# C     2160
# B     1635
# H      706
# I      353
# K      185
# L        1
# Name: assigned_room_type, dtype: int64

# %%
# Visualizing using bar chart

plt.figure(figsize = (20,8))
df['assigned_room_type'].value_counts().plot(kind = 'bar', color = 'g')
plt.title("Preffered Room types")
plt.xlabel("Room types")
plt.ylabel("Number of Guests")
plt.xticks(rotation = 360)
plt.show()

# %% [markdown]
# ## Observation
# * Most preffered Room type is A

# %% [markdown]
# ## 12. In which month most of the bookings happened?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting the value counts

monthly_arrival = df['arrival_date_month'].value_counts()
monthly_arrival
# Out:
# August       11210
# July         10011
# May           8329
# April         7879
# June          7746
# March         7473
# October       6905
# September     6671
# February      6065
# December      5091
# November      4967
# January       4667
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# ## Since the Months are not sorted. lets sort it

# %%
# Giving the sorting index

lis =  ['January','February','March','April','May','June','July','August','September','October','November','December']
monthly_arrival.index = pd.CategoricalIndex(monthly_arrival.index, categories = lis, ordered = False)

# %%
# Sorting with respect to the list which we passed

monthly_arrival.sort_index(inplace = True)
monthly_arrival
# Out:
# January       4667
# February      6065
# March         7473
# April         7879
# May           8329
# June          7746
# July         10011
# August       11210
# September     6671
# October       6905
# November      4967
# December      5091
# Name: arrival_date_month, dtype: int64

# %%
monthly_arrival.values
# Out:
# array([ 4667,  6065,  7473,  7879,  8329,  7746, 10011, 11210,  6671,
#         6905,  4967,  5091], dtype=int64)

# %%
# Now visualizing with bar graph

plt.figure(figsize = (15,6))
plt.bar(monthly_arrival.keys(), monthly_arrival, color = 'b')
plt.title("Monthly Guest Visited")
plt.xlabel("Months")
plt.ylabel("Number of guests")
plt.grid()
plt.show()

# %% [markdown]
#  ## Observation
#  * July and August months had the most Bookings.
#  * May be because fo the normal weather this bookings are high at this time.

# %% [markdown]
# ## 13. Which Distribution channel is mostly used for hotel bookings?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting unique values

df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
# Getting the value counts

df['distribution_channel'].value_counts()
# Out:
# TA/TO        68844
# Direct       12922
# Corporate     5062
# GDS            181
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
# Visualizing Through Bar Graph

plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
df['distribution_channel'].value_counts().plot(kind = 'bar', color = 'r')
plt.title("Mostly used distribution channel")
plt.xlabel("distribution_channel")
plt.ylabel("Number of Guests")
plt.xticks(rotation = 360)

# Visualizing Through Pie Graph

plt.subplot(1,2,2)
df['distribution_channel'].value_counts().plot(kind = 'pie',  
                                            shadow = True, autopct='%1.2f%%')
plt.legend(df['distribution_channel'].value_counts().keys())
plt.title('Mostly used distribution channel')
plt.show()

# %% [markdown]
# ## Observation
# * 'TA/TO' is mostly(79.1%) used for booking hotels.

# %% [markdown]
# # Bivariate Analysis
# ## Which year had the highest hotel bookings?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Now visualizing with bar graph

plt.figure(figsize = (15,6))
sns.countplot(x = df['arrival_date_year'], hue = df['hotel'])
plt.title("Hotel bookings with respect to year")
plt.xlabel("Year")
plt.ylabel("Number of guests")
plt.show()

# %% [markdown]
# ## Observation
# * 2016 had the higest bookings.
# * 2015 had least bookings.
# * overall City hotels had the most of the bookings.

# %% [markdown]
# ## Which Hotel type has  the highest ADR?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Grouping wrt hotel and counting ADR for them

hotel_adr = df.groupby(['hotel'])['adr'].count()
hotel_adr
# Out:
# hotel
# City Hotel      53058
# Resort Hotel    33956
# Name: adr, dtype: int64

# %%
# visualizing with bar graph

plt.figure(figsize = (8,6))
plt.bar(hotel_adr.keys(), hotel_adr, color = 'y')
plt.title("Hotel with ADR")
plt.xlabel("Hotel")
plt.ylabel("Hotel")
plt.show()

# %% [markdown]
# ### Observation
# * City hotel has the highest ADR.
# * That means city hotels are generating more revenues than the resort hotels.
# * More the ADR more is the revenue.

# %% [markdown]
# ## Which hotel type has the more lead time?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Grouping wrt hotel and finding average lead time for them


hotel_lead_time = df.groupby(['hotel'])['lead_time'].mean()
hotel_lead_time
# Out:
# hotel
# City Hotel      77.602492
# Resort Hotel    83.387737
# Name: lead_time, dtype: float64

# %%
# visualizing with bar graph

plt.figure(figsize = (8,6))
plt.bar(hotel_lead_time.keys(), hotel_lead_time, color = 'm')
plt.title("Hotel with ADR")
plt.xlabel("Hotel")
plt.ylabel("mean of lead time")
plt.show()

# %% [markdown]
# ## Observation
# * Resort hotels has slightly  high avg lead time. That means customers plan their trips very early.

# %% [markdown]
# ## Which hotel has highest percentage of booking cancellation?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Grouping wrt hotel and finding count of cancelled.

hotel_canceled = df.groupby(['hotel'])['is_canceled'].count()
hotel_canceled
# Out:
# hotel
# City Hotel      53058
# Resort Hotel    33956
# Name: is_canceled, dtype: int64

# %%
# visualizing with bar graph

plt.figure(figsize = (8,6))
plt.bar(hotel_canceled.keys(), hotel_canceled, color = 'b')
plt.title("booking cancellation")
plt.xlabel("Hotel")
plt.ylabel("is cancelled")
plt.show()

# %% [markdown]
# ## Which hotel has longer waiting time?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
hotel_waiting_list = df.groupby(['hotel'])['days_in_waiting_list'].count()
hotel_waiting_list
# Out:
# hotel
# City Hotel      53058
# Resort Hotel    33956
# Name: days_in_waiting_list, dtype: int64

# %%
# visualizing with bar graph

plt.figure(figsize = (8,6))
plt.bar(hotel_waiting_list.keys(), hotel_waiting_list, color = 'g')
plt.title("Hotel waiting List")
plt.xlabel("Hotel")
plt.ylabel("Waiting")
plt.show()

# %% [markdown]
# ## Observation
# * The City Hotels has longer waiting period than the Resort Hotels.
# * We can say that City Hotels are much busier than the Resort Hotels

# %% [markdown]
# ## Which Hotels has the most repeated guests?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# repeated guest=1
# not repeated guest=0
# Only taking repeated guests

hotel_repeated_guest = df[df['is_repeated_guest']==1].groupby(['hotel'])['is_repeated_guest'].count()
hotel_repeated_guest
# Out:
# hotel
# City Hotel      1656
# Resort Hotel    1707
# Name: is_repeated_guest, dtype: int64

# %%
# Visualizing Through Bar Graph

plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
plt.bar(hotel_repeated_guest.keys(),  hotel_repeated_guest, color ='m')
plt.title("Hotel with most repeated guests")
plt.xlabel("Hotels")
plt.ylabel("Number of Guests")

# Visualizing Through Pie Graph

plt.subplot(1,2,2)
textprops = {"fontsize":15} # Font size of text in pie chart
plt.pie(hotel_repeated_guest,  shadow = True, autopct='%1.2f%%', textprops =textprops)
plt.legend(hotel_repeated_guest.keys())
plt.title('Hotel with most repeated guests')
plt.show()

# %% [markdown]
# ## Observation
# * Resort Hotel has slightly more repeated guests than the City Hotels. It is almost similar for both hotels.

# %% [markdown]
# ## Multivariate analysis

# %% [markdown]
# ## ADR across the different month.

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Grouping arrival month and hotel with respect to adr

adr_months = df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
adr_months
# Out:
#    arrival_date_month         hotel         adr
# 0               April    City Hotel  117.438491
# 1               April  Resort Hotel   79.283805
# 2              August    City Hotel  125.353829
# 3              August  Resort Hotel  187.566659
# 4            December    City Hotel   93.395741
# 5            December  Resort Hotel   65.488671
# 6            February    City Hotel   89.371926
# 7            February  Resort Hotel   54.102809
# 8             January    City Hotel   85.515602
# 9             January  Resort Hotel   49.181693
# 10               July    City Hotel  120.569091
# 11               July  Resort Hotel  156.166914
# 12               June    City Hotel  124.050535
# 13               June  Resort Hotel  112.380859
# 14              March    City Hotel   95.255790
# 15              March  Resort Hotel   57.590889
# 16                May    City Hotel  128.090815
# 17                May  Resort Hotel   80.551101
# 18           November    City Hotel   89.912308
# ...

# %%
# using the lis which was already created for above question.
adr_months['arrival_date_month']=pd.Categorical(adr_months['arrival_date_month'],categories=lis,ordered=False)
adr_months['arrival_date_month']
# Out:
# 0         April
# 1         April
# 2        August
# 3        August
# 4      December
# 5      December
# 6      February
# 7      February
# 8       January
# 9       January
# 10         July
# 11         July
# 12         June
# 13         June
# 14        March
# 15        March
# 16          May
# 17          May
# 18     November
# 19     November
# 20      October
# 21      October
# 22    September
# 23    September
# Name: arrival_date_month, dtype: category
# Categories (12, object): ['January', 'February', 'March', 'April', ..., 'September', 'October', 'November', 'December']

# %%
# sorting
adr_months=adr_months.sort_values('arrival_date_month')
adr_months
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.515602
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.371926
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.255790
# 0               April    City Hotel  117.438491
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.090815
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  124.050535
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.569091
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.353829
# 22          September    City Hotel  118.759391
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.678665
# ...

# %%
# visualizing with bar graph

plt.figure(figsize = (15,6))
sns.lineplot(adr_months['arrival_date_month'], adr_months['adr'], hue = adr_months['hotel'])
plt.title("ADR across different months")
plt.xlabel("Months")
plt.ylabel("adr mean")
plt.grid()
plt.show()

# %% [markdown]
# ## Observation
#
# * For Resort hotel is ADR is high in the months July and August as compared to City Hotels.
#
# * The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the average daily rate in these months are very low.

# %% [markdown]
# ## Which distribution channel contributed more to adr in order to increase the the income?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Getting Unique values

df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
# Grouping it with distribution channel and hotel and calculating the mean of adr

distribution_channel_adr = df.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
distribution_channel_adr
# Out:
#   distribution_channel         hotel         adr
# 0            Corporate    City Hotel   83.777368
# 1            Corporate  Resort Hotel   53.036835
# 2               Direct    City Hotel  112.979656
# 3               Direct  Resort Hotel  106.566215
# 4                  GDS    City Hotel  120.317845
# 5                TA/TO    City Hotel  112.768361
# 6                TA/TO  Resort Hotel  101.578317
# 7            Undefined    City Hotel   29.625000
# 8            Undefined  Resort Hotel  112.700000

# %%
# Visualizing using barplot

plt.figure(figsize = (15,6))
sns.barplot(x = 'distribution_channel', y = 'adr',
              data = distribution_channel_adr, hue = 'hotel')
plt.title('contribution by distribution Channel for adr to increase revenue')
plt.xlabel('distribution Channel')
plt.ylabel('adr mean')
plt.show()

# %% [markdown]
# * Corporate- These are corporate hotel booking companies which makes bookings possible.
# * GDS-A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# * Direct- means that bookings are directly made with the respective hotels
# * TA/TO- means that booings are made through  travel agents or travel operators.
# * Undefined- Bookings are undefined. may be customers made their bookings on arrival.

# %% [markdown]
# ## Observation
#
# * 'Direct' and 'TA/TO' has almost equally contributed in adr in both type of hotels i.e. 'City Hotel' and 'Resort Hotel'.
# * GDS has highly contributed in adr in 'City Hotel' type.
# * GDS needs to increase Resort Hotel bookings.

# %% [markdown]
# ## Which distribution channel has the highest cancellation rate?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Grouping by distribution channel and hotel with is_cancelled = 1

cancelled = df[df['is_canceled'] == 1]
distribution_channel_cancelled = cancelled.groupby(['distribution_channel', 'hotel'])['is_canceled'].count().reset_index()
distribution_channel_cancelled
# Out:
#   distribution_channel         hotel  is_canceled
# 0            Corporate    City Hotel          330
# 1            Corporate  Resort Hotel          316
# 2               Direct    City Hotel          964
# 3               Direct  Resort Hotel          952
# 4                  GDS    City Hotel           36
# 5                TA/TO    City Hotel        14621
# 6                TA/TO  Resort Hotel         6706
# 7            Undefined    City Hotel            4

# %%
# Visualizing through barplot

plt.figure(figsize = (15,6))
sns.barplot(x = 'distribution_channel', y = 'is_canceled' , data = distribution_channel_cancelled,
           hue = 'hotel')
plt.title('contribution by distribution Channel for adr to increase revenue')
plt.xlabel('distribution Channel')
plt.ylabel('adr mean')
plt.show()

# %% [markdown]
# ## Observation
#
# * In "TA/TO", City hotels has the high cancellation rate compared to resort hotels.
# * In "direct" both the hotels has almost same cancellation rate.

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
# Creating a new column based on if the guests are assigned with same room as they reserved

df.loc[df['reserved_room_type'] == df['assigned_room_type'], 'same_room'] = 1
df.loc[df['reserved_room_type'] != df['assigned_room_type'], 'same_room'] = 0
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults children  babies  \
# 0                        0                     0       2      0.0       0
# ...

# %%
df['same_room'].keys()
# Out:
# Int64Index([     0,      1,      2,      3,      4,      6,      7,      8,
#                  9,     10,
#             ...
#             119380, 119381, 119382, 119383, 119384, 119385, 119386, 119387,
#             119388, 119389],
#            dtype='int64', length=87014)

# %%
df['same_room'].value_counts()
# Out:
# 1.0    74056
# 0.0    12958
# Name: same_room, dtype: int64

# %%
#given = df[df['same_room'] == 1.0]
same_room_alloted = df.groupby(['hotel'])['same_room'].count()
same_room_alloted
# Out:
# hotel
# City Hotel      53058
# Resort Hotel    33956
# Name: same_room, dtype: int64

# %%
# Visualizing with bar graph

plt.figure(figsize = (10,6))
same_room_alloted.plot(kind = 'bar')
plt.xticks(rotation = 360)
plt.title("Number of guests alloted with the same room they booked ")
# Out:
# Text(0.5, 1.0, 'Number of guests alloted with the same room they booked ')

# %% [markdown]
# ## Observation
# * It looks like most of the guest in city hotels were alloted with the same room they reseved
# * In resort hotel they changed the room type more often than usual.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Business objective
#
# 1. For hotel business to flourish few things which we need to consider is high revenue generation, customers satisfaction and employeee retention.
#
# 2. We are able achieve the same by showing the client which are the months which are high in revenue generation by pie chart distribution
#
# 3. Increasing the revenue achieved by bar chart distribution of which typre room are most reserved and what are the months likely for visitors
#
# 4. So for these the client can be well prepare in advance so that minimum grievances would be faced by clients in long run and would help in further enhancement of their hospitality.
#
# 5. Outliers like higher the visitor then adr has reduced drastically was shown in scattered plot so in off season client can engage with offices for bulk booking this will aslo help extra revenue generation
#
# 6. We are able to show the trend of arrivals of visitor at client locations through which client engaged visitos well advance for there entaertainment and leisure activities
#
# 7. We where also able to co relate the values showing the max and min percentage between them so that the percenytage lying those numbers can be enhanced by various medium

# %% [markdown]
# ## Conclusion
#
# 1.	City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
# 2.	27.5 % bookings were got cancelled out of all the bookings.
# 3.	Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
# 4.	The percentage of 0 changes made in the booking was more than 82 %.  Percentage of Single changes made was about 10%.
# 5.	Most of the customers (91.6%) do not require car parking spaces.
# 6.	79.1 % bookings were made through TA/TO (travel agents/Tour operators).
# 7.	BB( Bed & Breakfast) is the most preferred  type of meal by the guests.
# 8.	Maximum number of guests were from Portugal, i.e. more than 25000 guests.
# 9.	Most of the bookings for City hotels and Resort hotel were happened in 2016.
# 10.	Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
# 11.	Booking cancellation rate is high for City hotels which almost 30 %.
# 12.	Average lead time for resort hotel is high.
# 13.	Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
# 14.	Resort hotels have the most repeated guests.
# 15.	Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
# 16.	Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.
